# %% [markdown]
# # Updating rows and columns and modifying Data

# %%
import pandas as pd

# %%
people = {
    'first_name':['Corey','Jane','John'],
    'last_name':['Schafer','Doe','Doe'],
    'email':['CoreySchafer@gmail.com','janeDoe@gmail.com','JohnDoe@gmail.com']
}

# %%
people_df = pd.DataFrame(people)

# %%
people_df
# Out:
#   first_name last_name                   email
# 0      Corey   Schafer  CoreySchafer@gmail.com
# 1       Jane       Doe       janeDoe@gmail.com
# 2       John       Doe       JohnDoe@gmail.com

# %%
people_df.columns
# Out:
# Index(['first_name', 'last_name', 'email'], dtype='object')

# %% [markdown]
# # Updating Columns

# %%
people_df.columns = ['first','last','email']

# %%
people_df
# Out:
#    first     last                   email
# 0  Corey  Schafer  CoreySchafer@gmail.com
# 1   Jane      Doe       janeDoe@gmail.com
# 2   John      Doe       JohnDoe@gmail.com

# %%
#uppercasing all of the columns names
people_df.columns = [x.upper() for x in people_df.columns]

# %%
people_df
# Out:
#    FIRST     LAST                   EMAIL
# 0  Corey  Schafer  CoreySchafer@gmail.com
# 1   Jane      Doe       janeDoe@gmail.com
# 2   John      Doe       JohnDoe@gmail.com

# %%
people_df.columns = ['first_name','last_name','email']

# %%
people_df
# Out:
#   first_name last_name                   email
# 0      Corey   Schafer  CoreySchafer@gmail.com
# 1       Jane       Doe       janeDoe@gmail.com
# 2       John       Doe       JohnDoe@gmail.com

# %%
#method to replace characters with each other
people_df.columns = people_df.columns.str.replace('_',' ')

# %%
people_df
# Out:
#   first name last name                   email
# 0      Corey   Schafer  CoreySchafer@gmail.com
# 1       Jane       Doe       janeDoe@gmail.com
# 2       John       Doe       JohnDoe@gmail.com

# %%
people_df.columns = people_df.columns.str.replace(' ','_')

# %%
people_df
# Out:
#   first_name last_name                   email
# 0      Corey   Schafer  CoreySchafer@gmail.com
# 1       Jane       Doe       janeDoe@gmail.com
# 2       John       Doe       JohnDoe@gmail.com

# %%
#modifying specific columns instead of all the columns
people_df.rename(columns={'first_name':'first','last_name':'last'}, inplace = True)

# %%
people_df
# Out:
#    first     last                   email
# 0  Corey  Schafer  CoreySchafer@gmail.com
# 1   Jane      Doe       janeDoe@gmail.com
# 2   John      Doe       JohnDoe@gmail.com

# %%
#modifying specific data in our rows
people_df.loc[2] = ['John','Smith','JohnSmith@gmail.com']

# %%
people_df
# Out:
#    first     last                   email
# 0  Corey  Schafer  CoreySchafer@gmail.com
# 1   Jane      Doe       janeDoe@gmail.com
# 2   John    Smith     JohnSmith@gmail.com

# %%
#changing a single columns when there are many
people_df.loc[2,['last','email']] = ['Doe','JohnDoe@gmail.com']

# %%
people_df
# Out:
#    first     last                   email
# 0  Corey  Schafer  CoreySchafer@gmail.com
# 1   Jane      Doe       janeDoe@gmail.com
# 2   John      Doe       JohnDoe@gmail.com

# %%
#changing single values
people_df.loc[2,'last'] = 'Gupta'

# %%
people_df
# Out:
#    first     last                   email
# 0  Corey  Schafer  CoreySchafer@gmail.com
# 1   Jane      Doe       janeDoe@gmail.com
# 2   John    Gupta       JohnDoe@gmail.com

# %%
filt = (people_df['email'] == 'JohnDoe@gmail.com')
people_df[filt]['last']
# Out:
# 2    Gupta
# Name: last, dtype: object

# %%
#updating values of multiple rows
people_df['email'] = people_df['email'].str.lower()

# %%
people_df
# Out:
#    first     last                   email
# 0  Corey  Schafer  coreyschafer@gmail.com
# 1   Jane      Doe       janedoe@gmail.com
# 2   John    Smith       johndoe@gmail.com

# %%
# 4methods
# apply
# map
# applymap
# replace

#apply applies a function to a series or a dataframe
people_df['email'].apply(len)
# Out:
# 0    22
# 1    17
# 2    17
# Name: email, dtype: int64

# %%
def update_email(email):
  return email.upper()

people_df['email'].apply(update_email)
# Out:
# 0    COREYSCHAFER@GMAIL.COM
# 1         JANEDOE@GMAIL.COM
# 2         JOHNDOE@GMAIL.COM
# Name: email, dtype: object

# %%
people_df['email'] = people_df['email'].apply(update_email)

# %%
people_df
# Out:
#    first     last                   email
# 0  Corey  Schafer  COREYSCHAFER@GMAIL.COM
# 1   Jane      Doe       JANEDOE@GMAIL.COM
# 2   John    Smith       JOHNDOE@GMAIL.COM

# %%
people_df['email'] = people_df['email'].apply(lambda x: x.lower())

# %%
people_df
# Out:
#    first     last                   email
# 0  Corey  Schafer  coreyschafer@gmail.com
# 1   Jane      Doe       janedoe@gmail.com
# 2   John    Smith       johndoe@gmail.com

# %%
#apply working on dataFrames
# runs a function on each row or column of that data frame

people_df.apply(len) #default is rows
# Out:
# first    3
# last     3
# email    3
# dtype: int64

# %%
people_df.apply(len, axis = 'columns')
# Out:
# 0    3
# 1    3
# 2    3
# dtype: int64

# %%
#using apply to grab the minimum value from our series 

people_df.apply(pd.Series.min)  #checks for each column
# Out:
# first                     Corey
# last                        Doe
# email    coreyschafer@gmail.com
# dtype: object

# %%
people_df.apply(lambda x: x.min()) # x is a series return the minimun of that series
# Out:
# first                     Corey
# last                        Doe
# email    coreyschafer@gmail.com
# dtype: object

# %%
#apply map is used to apply a function to every individual value in a data frame
# only works on data frames

people_df.applymap(min)  #these are series method
# Out:
#   first last email
# 0     C    S     .
# 1     J    D     .
# 2     J    S     .

# %%
people_df.applymap(len)
# Out:
#    first  last  email
# 0      5     7     22
# 1      4     3     17
# 2      4     5     17

# %%
people_df.applymap(str.upper)
# Out:
#    first     last                   email
# 0  COREY  SCHAFER  COREYSCHAFER@GMAIL.COM
# 1   JANE      DOE       JANEDOE@GMAIL.COM
# 2   JOHN    SMITH       JOHNDOE@GMAIL.COM

# %%
people_df
# Out:
#    first     last                   email
# 0  Corey  Schafer  coreyschafer@gmail.com
# 1   Jane      Doe       janedoe@gmail.com
# 2   John    Smith       johndoe@gmail.com

# %%
#map only works on a series
#it is used to substitue values with another values
people_df['first'].map({'Corey':'Chris','Jane':'Mary'})

#for the values that does not get passed in it returns NAN
# Out:
# 0    Chris
# 1     Mary
# 2      NaN
# Name: first, dtype: object

# %%
people_df
# Out:
#    first     last                   email
# 0  Corey  Schafer  coreyschafer@gmail.com
# 1   Jane      Doe       janedoe@gmail.com
# 2   John    Smith       johndoe@gmail.com

# %%
people_df['first'].replace({'Corey':'Chris','Jane':'Mary'})
# Out:
# 0    Chris
# 1     Mary
# 2     John
# Name: first, dtype: object

# %%
people_df
# Out:
#    first     last                   email
# 0  Corey  Schafer  coreyschafer@gmail.com
# 1   Jane      Doe       janedoe@gmail.com
# 2   John    Smith       johndoe@gmail.com

# %%
schema_df = pd.read_csv('/content/survey_results_schema.csv')
df = pd.read_csv('/content/survey_results_public.csv')

# %%
pd.set_option('display.max_columns',85)
pd.set_option('display.max_rows',85)

# %%
df
# Out:
#       Respondent                                         MainBranch Hobbyist  \
# 0              1             I am a student who is learning to code      Yes
# 1              2             I am a student who is learning to code       No
# 2              3  I am not primarily a developer, but I write co...      Yes
# 3              4                     I am a developer by profession       No
# 4              5                     I am a developer by profession      Yes
# ...          ...                                                ...      ...
# 9901        9943                     I am a developer by profession      Yes
# 9902        9944                     I am a developer by profession      Yes
# 9903        9945             I am a student who is learning to code      Yes
# 9904        9946                     I am a developer by profession       No
# 9905        9947                     I am a developer by profession      Yes
#
#                                             OpenSourcer  \
# 0                                                 Never
# 1                               Less than once per year
# 2                                                 Never
# 3                                                 Never
# 4                            Once a month or more often
# ...                                                 ...
# 9901                                              Never
# 9902                            Less than once per year
# 9903  Less than once a month but more than once per ...
# 9904  Less than once a month but more than once per ...
# 9905                            Less than once per year
#
#                                              OpenSource  \
# 0     The quality of OSS and closed source software ...
# 1     The quality of OSS and closed source software ...
# 2     The quality of OSS and closed source software ...
# 3     The quality of OSS and closed source software ...
# 4     OSS is, on average, of HIGHER quality than pro...
# ...                                                 ...
# 9901  OSS is, on average, of HIGHER quality than pro...
# 9902  The quality of OSS and closed source software ...
# 9903  The quality of OSS and closed source software ...
# 9904  OSS is, on average, of HIGHER quality than pro...
# 9905  OSS is, on average, of HIGHER quality than pro...
#
#                                   Employment                 Country  \
# 0     Not employed, and not looking for work          United Kingdom
# 1         Not employed, but looking for work  Bosnia and Herzegovina
# 2                         Employed full-time                Thailand
# 3                         Employed full-time           United States
# 4                         Employed full-time                 Ukraine
# ...                                      ...                     ...
# 9901                      Employed full-time                 Ukraine
# 9902                      Employed full-time                   India
# 9903                      Employed part-time           United States
# 9904                      Employed full-time           United States
# 9905                      Employed full-time           United States
#
#              Student                                            EdLevel  \
# 0                 No                          Primary/elementary school
# 1     Yes, full-time  Secondary school (e.g. American high school, G...
# 2                 No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 3                 No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4                 No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# ...              ...                                                ...
# 9901  Yes, full-time        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 9902             NaN           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 9903  Yes, full-time                                   Associate degree
# 9904              No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 9905              No           Bachelor’s degree (BA, BS, B.Eng., etc.)
#
#                                          UndergradMajor  \
# 0                                                   NaN
# 1                                                   NaN
# 2                         Web development or web design
# 3     Computer science, computer engineering, or sof...
# 4     Computer science, computer engineering, or sof...
# ...                                                 ...
# 9901  Computer science, computer engineering, or sof...
# 9902  Information systems, information technology, o...
# 9903  Computer science, computer engineering, or sof...
# 9904  Computer science, computer engineering, or sof...
# 9905  Another engineering discipline (ex. civil, ele...
#
#                                                EduOther  \
# 0     Taught yourself a new language, framework, or ...
# 1     Taken an online course in programming or softw...
# 2     Taught yourself a new language, framework, or ...
# 3     Taken an online course in programming or softw...
# 4     Taken an online course in programming or softw...
# ...                                                 ...
# 9901  Taken an online course in programming or softw...
# 9902  Taken an online course in programming or softw...
# 9903  Taken an online course in programming or softw...
# 9904  Taught yourself a new language, framework, or ...
# 9905  Taught yourself a new language, framework, or ...
#
#                        OrgSize  \
# 0                          NaN
# 1                          NaN
# 2         100 to 499 employees
# 3         100 to 499 employees
# 4     10,000 or more employees
# ...                        ...
# 9901        20 to 99 employees
# 9902  10,000 or more employees
# 9903                       NaN
# 9904      500 to 999 employees
# 9905  1,000 to 4,999 employees
#
#                                                 DevType YearsCode Age1stCode  \
# 0                                                   NaN         4         10
# 1     Developer, desktop or enterprise applications;...       NaN         17
# 2     Designer;Developer, back-end;Developer, front-...         3         22
# 3                                 Developer, full-stack         3         16
# 4     Academic researcher;Developer, desktop or ente...        16         14
# ...                                                 ...       ...        ...
# 9901                                Developer, back-end         9         15
# 9902  Developer, back-end;Developer, desktop or ente...         4         20
# 9903  Developer, back-end;Developer, front-end;Devel...         6         14
# 9904  Developer, embedded applications or devices;De...         8         15
# 9905  Developer, back-end;Developer, front-end;Devel...        22          9
#
#           YearsCodePro              CareerSat  \
# 0                  NaN                    NaN
# 1                  NaN                    NaN
# 2                    1     Slightly satisfied
# 3     Less than 1 year         Very satisfied
# 4                    9      Very dissatisfied
# ...                ...                    ...
# 9901                 4     Slightly satisfied
# 9902                 4  Slightly dissatisfied
# 9903               NaN                    NaN
# 9904                 2     Slightly satisfied
# 9905                10         Very satisfied
#
#                                   JobSat              MgrIdiot  MgrMoney  \
# 0                                    NaN                   NaN       NaN
# 1                                    NaN                   NaN       NaN
# 2                     Slightly satisfied  Not at all confident  Not sure
# 3                     Slightly satisfied        Very confident        No
# 4                  Slightly dissatisfied    Somewhat confident       Yes
# ...                                  ...                   ...       ...
# 9901                  Slightly satisfied        Very confident  Not sure
# 9902  Neither satisfied nor dissatisfied    Somewhat confident  Not sure
# 9903                                 NaN                   NaN       NaN
# 9904  Neither satisfied nor dissatisfied        Very confident  Not sure
# 9905                      Very satisfied        Very confident       Yes
#
#        MgrWant                                            JobSeek  \
# 0          NaN                                                NaN
# 1          NaN                    I am actively looking for a job
# 2     Not sure  I’m not actively looking, but I am open to new...
# 3     Not sure       I am not interested in new job opportunities
# 4           No       I am not interested in new job opportunities
# ...        ...                                                ...
# 9901       Yes       I am not interested in new job opportunities
# 9902       Yes                    I am actively looking for a job
# 9903       NaN  I’m not actively looking, but I am open to new...
# 9904       Yes                    I am actively looking for a job
# 9905        No  I’m not actively looking, but I am open to new...
#
#                LastHireDate  \
# 0                       NaN
# 1      I've never had a job
# 2             1-2 years ago
# 3      Less than a year ago
# 4      Less than a year ago
# ...                     ...
# 9901   Less than a year ago
# 9902          1-2 years ago
# 9903   Less than a year ago
# 9904          1-2 years ago
# 9905  More than 4 years ago
#
#                                                 LastInt FizzBuzz  \
# 0                                                   NaN      NaN
# 1                                                   NaN      NaN
# 2                   Interview with people in peer roles       No
# 3     Write code by hand (e.g., on a whiteboard);Int...       No
# 4     Write any code;Write code by hand (e.g., on a ...       No
# ...                                                 ...      ...
# 9901  Interview with people in peer roles;Interview ...      Yes
# 9902         Write code by hand (e.g., on a whiteboard)       No
# 9903                                                NaN      NaN
# 9904  Write any code;Interview with people in peer r...       No
# 9905  Write any code;Write code by hand (e.g., on a ...       No
#
#                                              JobFactors  \
# 0                                                   NaN
# 1     Financial performance or funding status of the...
# 2     Languages, frameworks, and other technologies ...
# 3     Languages, frameworks, and other technologies ...
# 4     Industry that I'd be working in;Languages, fra...
# ...                                                 ...
# 9901  Languages, frameworks, and other technologies ...
# 9902  Languages, frameworks, and other technologies ...
# 9903  Specific department or team I'd be working on;...
# 9904  Languages, frameworks, and other technologies ...
# 9905  Financial performance or funding status of the...
#
#                                            ResumeUpdate CurrencySymbol  \
# 0                                                   NaN            NaN
# 1     Something else changed (education, award, medi...            NaN
# 2                      I was preparing for a job search            THB
# 3                      I was preparing for a job search            USD
# 4                      I was preparing for a job search            UAH
# ...                                                 ...            ...
# 9901   My job status changed (promotion, new job, etc.)            UAH
# 9902                   I was preparing for a job search            INR
# 9903   My job status changed (promotion, new job, etc.)            NaN
# 9904                   I was preparing for a job search            USD
# 9905  Something else changed (education, award, medi...            USD
#
#               CurrencyDesc  CompTotal CompFreq  ConvertedComp  WorkWeekHrs  \
# 0                      NaN        NaN      NaN            NaN          NaN
# 1                      NaN        NaN      NaN            NaN          NaN
# 2                Thai baht    23000.0  Monthly         8820.0         40.0
# 3     United States dollar    61000.0   Yearly        61000.0         80.0
# 4        Ukrainian hryvnia        NaN      NaN            NaN         55.0
# ...                    ...        ...      ...            ...          ...
# 9901     Ukrainian hryvnia    64000.0  Monthly        27696.0         40.0
# 9902          Indian rupee        NaN  Monthly            NaN         40.0
# 9903                   NaN        NaN      NaN            NaN          NaN
# 9904  United States dollar    75000.0   Yearly        75000.0         35.0
# 9905  United States dollar   117000.0   Yearly       117000.0         45.0
#
#                                                WorkPlan  \
# 0                                                   NaN
# 1                                                   NaN
# 2     There's no schedule or spec; I work on what se...
# 3     There's no schedule or spec; I work on what se...
# 4     There is a schedule and/or spec (made by me or...
# ...                                                 ...
# 9901  There's no schedule or spec; I work on what se...
# 9902  There's no schedule or spec; I work on what se...
# 9903                                                NaN
# 9904  There is a schedule and/or spec (made by me or...
# 9905  There is a schedule and/or spec (made by me or...
#
#                                           WorkChallenge  \
# 0                                                   NaN
# 1                                                   NaN
# 2     Distracting work environment;Inadequate access...
# 3                                                   NaN
# 4     Being tasked with non-development work;Inadequ...
# ...                                                 ...
# 9901  Distracting work environment;Lack of support f...
# 9902             Being tasked with non-development work
# 9903                                                NaN
# 9904  Inadequate access to necessary tools;Meetings;...
# 9905  Being tasked with non-development work;Distrac...
#
#                                              WorkRemote WorkLoc  \
# 0                                                   NaN     NaN
# 1                                                   NaN     NaN
# 2                      Less than once per month / Never    Home
# 3                      Less than once per month / Never    Home
# 4                                 A few days each month  Office
# ...                                                 ...     ...
# 9901                   Less than once per month / Never  Office
# 9902              More than half, but not all, the time  Office
# 9903                                                NaN     NaN
# 9904  All or almost all the time (I'm full-time remote)  Office
# 9905                              A few days each month  Office
#
#                       ImpSyn                                  CodeRev  \
# 0                        NaN                                      NaN
# 1                        NaN                                      NaN
# 2                    Average                                       No
# 3     A little below average                                       No
# 4     A little above average  Yes, because I see value in code review
# ...                      ...                                      ...
# 9901                 Average  Yes, because I see value in code review
# 9902       Far above average  Yes, because I see value in code review
# 9903                     NaN                                      NaN
# 9904       Far above average  Yes, because I see value in code review
# 9905                 Average  Yes, because I see value in code review
#
#       CodeRevHrs                                          UnitTests  \
# 0            NaN                                                NaN
# 1            NaN                                                NaN
# 2            NaN                          No, but I think we should
# 3            NaN                          No, but I think we should
# 4            NaN                      Yes, it's part of our process
# ...          ...                                                ...
# 9901        10.0                      Yes, it's part of our process
# 9902         5.0                      Yes, it's part of our process
# 9903         NaN                                                NaN
# 9904         2.0                          No, but I think we should
# 9905         5.0  Yes, it's not part of our process but the deve...
#
#                                             PurchaseHow  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                              Not sure
# 3     Developers typically have the most influence o...
# 4                                              Not sure
# ...                                                 ...
# 9901                                           Not sure
# 9902                                           Not sure
# 9903                                                NaN
# 9904  Developers and management have nearly equal in...
# 9905                                           Not sure
#
#                           PurchaseWhat  \
# 0                                  NaN
# 1                                  NaN
# 2        I have little or no influence
# 3        I have little or no influence
# 4        I have little or no influence
# ...                                ...
# 9901             I have some influence
# 9902     I have little or no influence
# 9903                               NaN
# 9904  I have a great deal of influence
# 9905     I have little or no influence
#
#                                      LanguageWorkedWith  \
# 0                       HTML/CSS;Java;JavaScript;Python
# 1                                   C++;HTML/CSS;Python
# 2                                              HTML/CSS
# 3                                   C;C++;C#;Python;SQL
# 4           C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
# ...                                                 ...
# 9901  Bash/Shell/PowerShell;HTML/CSS;JavaScript;PHP;SQL
# 9902                                Java;JavaScript;SQL
# 9903     C++;C#;HTML/CSS;Java;JavaScript;SQL;TypeScript
# 9904                                               C;C#
# 9905                         Java;JavaScript;Kotlin;SQL
#
#                                  LanguageDesireNextYear  \
# 0       C;C++;C#;Go;HTML/CSS;Java;JavaScript;Python;SQL
# 1                           C++;HTML/CSS;JavaScript;SQL
# 2                                       Elixir;HTML/CSS
# 3                                   C;C#;JavaScript;SQL
# 4              HTML/CSS;Java;JavaScript;SQL;WebAssembly
# ...                                                 ...
# 9901  Bash/Shell/PowerShell;HTML/CSS;JavaScript;PHP;SQL
# 9902                          Java;JavaScript;Other(s):
# 9903              C#;HTML/CSS;JavaScript;SQL;TypeScript
# 9904                                 C#;Rust;TypeScript
# 9905                    C++;Erlang;Go;JavaScript;Kotlin
#
#                                     DatabaseWorkedWith  \
# 0                                               SQLite
# 1                                                  NaN
# 2                                           PostgreSQL
# 3                                         MySQL;SQLite
# 4     Couchbase;MongoDB;MySQL;Oracle;PostgreSQL;SQLite
# ...                                                ...
# 9901                               MongoDB;MySQL;Redis
# 9902                                             MySQL
# 9903                 Microsoft SQL Server;MySQL;SQLite
# 9904                                             MySQL
# 9905                       Microsoft SQL Server;SQLite
#
#                                  DatabaseDesireNextYear  \
# 0                                                 MySQL
# 1                                                 MySQL
# 2                                            PostgreSQL
# 3                                          MySQL;SQLite
# 4     Couchbase;Firebase;MongoDB;MySQL;Oracle;Postgr...
# ...                                                 ...
# 9901                                MongoDB;MySQL;Redis
# 9902                                      MongoDB;MySQL
# 9903                  Microsoft SQL Server;MySQL;SQLite
# 9904                             DynamoDB;MongoDB;MySQL
# 9905                                                NaN
#
#                      PlatformWorkedWith  \
# 0                         MacOS;Windows
# 1                               Windows
# 2                                   NaN
# 3                         Linux;Windows
# 4     Android;Linux;MacOS;Slack;Windows
# ...                                 ...
# 9901                       Docker;Linux
# 9902                  AWS;Linux;Windows
# 9903                                NaN
# 9904                        Android;iOS
# 9905                            Android
#
#                        PlatformDesireNextYear  \
# 0                     Android;Arduino;Windows
# 1                                     Windows
# 2                                         NaN
# 3                               Linux;Windows
# 4       Android;Docker;Kubernetes;Linux;Slack
# ...                                       ...
# 9901                             Docker;Linux
# 9902  AWS;Google Cloud Platform;Linux;Windows
# 9903                                      NaN
# 9904    Android;Docker;iOS;Raspberry Pi;Slack
# 9905  Android;Arduino;AWS;Docker;Raspberry Pi
#
#                                WebFrameWorkedWith  \
# 0                                    Django;Flask
# 1                                          Django
# 2                                             NaN
# 3                                             NaN
# 4     Django;Express;Flask;jQuery;React.js;Spring
# ...                                           ...
# 9901                             jQuery;Other(s):
# 9902                                       jQuery
# 9903            Angular/Angular.js;ASP.NET;jQuery
# 9904                                          NaN
# 9905                                     React.js
#
#                  WebFrameDesireNextYear               MiscTechWorkedWith  \
# 0                          Flask;jQuery                          Node.js
# 1                                Django                              NaN
# 2                             Other(s):                              NaN
# 3                                   NaN                             .NET
# 4          Flask;jQuery;React.js;Spring                  Cordova;Node.js
# ...                                 ...                              ...
# 9901                 React.js;Other(s):                              NaN
# 9902              Express;jQuery;Spring                              NaN
# 9903  Angular/Angular.js;ASP.NET;jQuery           .NET;.NET Core;Node.js
# 9904     ASP.NET;React.js;Spring;Vue.js  .NET;.NET Core;Unity 3D;Xamarin
# 9905                           React.js                     React Native
#
#                            MiscTechDesireNextYear  \
# 0                                         Node.js
# 1                                             NaN
# 2                                             NaN
# 3                                            .NET
# 4        Apache Spark;Hadoop;Node.js;React Native
# ...                                           ...
# 9901                                      Node.js
# 9902                              Ansible;Node.js
# 9903                            .NET Core;Node.js
# 9904  Flutter;.NET;.NET Core;React Native;Xamarin
# 9905                                 React Native
#
#                                         DevEnviron        OpSys  \
# 0                       IntelliJ;Notepad++;PyCharm      Windows
# 1                                     Atom;PyCharm      Windows
# 2                           Vim;Visual Studio Code  Linux-based
# 3     Eclipse;Vim;Visual Studio;Visual Studio Code      Windows
# 4                           IntelliJ;Notepad++;Vim  Linux-based
# ...                                            ...          ...
# 9901                                      PHPStorm  Linux-based
# 9902            Eclipse;PyCharm;Visual Studio Code      Windows
# 9903    Notepad++;Visual Studio;Visual Studio Code      Windows
# 9904              Visual Studio;Visual Studio Code      Windows
# 9905      Android Studio;IntelliJ;Sublime Text;Vim        MacOS
#
#                                              Containers BlockchainOrg  \
# 0                               I do not use containers           NaN
# 1                               I do not use containers           NaN
# 2                               I do not use containers           NaN
# 3                               I do not use containers    Not at all
# 4                Outside of work, for personal projects    Not at all
# ...                                                 ...           ...
# 9901  Development;Outside of work, for personal proj...           NaN
# 9902                            I do not use containers           NaN
# 9903                            I do not use containers           NaN
# 9904                                                NaN    Not at all
# 9905                            I do not use containers    Not at all
#
#                                            BlockchainIs BetterLife  \
# 0                                                   NaN        Yes
# 1     Useful across many domains and could change ma...        Yes
# 2                                                   NaN        Yes
# 3     Useful for decentralized currency (i.e., Bitcoin)        Yes
# 4                                                   NaN        Yes
# ...                                                 ...        ...
# 9901                                                NaN        Yes
# 9902                                                NaN        Yes
# 9903                                                NaN         No
# 9904                                      A passing fad        Yes
# 9905                                                 An        NaN
#
#                                       ITperson  OffOn SocialMedia  \
# 0     Fortunately, someone else has that title    Yes     Twitter
# 1                                          Yes    Yes   Instagram
# 2                                          Yes    Yes      Reddit
# 3                                         SIGH    Yes      Reddit
# 4                                     Also Yes    Yes    Facebook
# ...                                        ...    ...         ...
# 9901                                       Yes  What?     YouTube
# 9902                                       Yes  What?   Instagram
# 9903                                  Also Yes     No     Twitter
# 9904                                  Also Yes    Yes     YouTube
# 9905                                       NaN    NaN         NaN
#
#                   Extraversion ScreenName        SOVisit1st  \
# 0                       Online   Username              2017
# 1                       Online   Username              2017
# 2     In real life (in person)   Username              2011
# 3     In real life (in person)   Username              2014
# 4     In real life (in person)   Username  I don't remember
# ...                        ...        ...               ...
# 9901  In real life (in person)   Username              2013
# 9902  In real life (in person)      Login              2013
# 9903                    Online   Username              2014
# 9904  In real life (in person)      Login  I don't remember
# 9905                       NaN        NaN               NaN
#
#                           SOVisitFreq  \
# 0     A few times per month or weekly
# 1               Daily or almost daily
# 2                A few times per week
# 3               Daily or almost daily
# 4              Multiple times per day
# ...                               ...
# 9901           Multiple times per day
# 9902           Multiple times per day
# 9903            Daily or almost daily
# 9904            Daily or almost daily
# 9905                              NaN
#
#                                               SOVisitTo  \
# 0     Find answers to specific questions;Learn how t...
# 1     Find answers to specific questions;Learn how t...
# 2     Find answers to specific questions;Learn how t...
# 3     Find answers to specific questions;Pass the ti...
# 4                    Find answers to specific questions
# ...                                                 ...
# 9901  Find answers to specific questions;Learn how t...
# 9902                 Find answers to specific questions
# 9903  Find answers to specific questions;Learn how t...
# 9904                 Find answers to specific questions
# 9905                                                NaN
#
#                      SOFindAnswer                         SOTimeSaved  \
# 0              3-5 times per week      Stack Overflow was much faster
# 1              3-5 times per week      Stack Overflow was much faster
# 2             6-10 times per week            They were about the same
# 3              1-2 times per week      Stack Overflow was much faster
# 4     More than 10 times per week      Stack Overflow was much faster
# ...                           ...                                 ...
# 9901          6-10 times per week      Stack Overflow was much faster
# 9902           3-5 times per week  Stack Overflow was slightly faster
# 9903           3-5 times per week  Stack Overflow was slightly faster
# 9904           1-2 times per week      Stack Overflow was much faster
# 9905                          NaN                                 NaN
#
#       SOHowMuchTime                  SOAccount  \
# 0     31-60 minutes                         No
# 1     11-30 minutes                        Yes
# 2               NaN                        Yes
# 3     31-60 minutes                        Yes
# 4               NaN                        Yes
# ...             ...                        ...
# 9901   0-10 minutes                        Yes
# 9902    60+ minutes                        Yes
# 9903  11-30 minutes  Not sure / can't remember
# 9904    60+ minutes                        Yes
# 9905            NaN                        NaN
#
#                                              SOPartFreq  \
# 0                                                   NaN
# 1                       A few times per month or weekly
# 2                   Less than once per month or monthly
# 3                   Less than once per month or monthly
# 4                       A few times per month or weekly
# ...                                                 ...
# 9901                Less than once per month or monthly
# 9902  I have never participated in Q&A on Stack Over...
# 9903                                                NaN
# 9904  I have never participated in Q&A on Stack Over...
# 9905                                                NaN
#
#                                                  SOJobs  \
# 0     No, I didn't know that Stack Overflow had a jo...
# 1     No, I knew that Stack Overflow had a job board...
# 2                                                   Yes
# 3                                                   Yes
# 4     No, I knew that Stack Overflow had a job board...
# ...                                                 ...
# 9901  No, I knew that Stack Overflow had a job board...
# 9902  No, I didn't know that Stack Overflow had a jo...
# 9903  No, I didn't know that Stack Overflow had a jo...
# 9904                                                Yes
# 9905                                                NaN
#
#                                                EntTeams           SOComm  \
# 0                   No, and I don't know what those are          Neutral
# 1                   No, and I don't know what those are    Yes, somewhat
# 2     No, I've heard of them, but I am not part of a...          Neutral
# 3                   No, and I don't know what those are   No, not really
# 4     No, I've heard of them, but I am not part of a...  Yes, definitely
# ...                                                 ...              ...
# 9901                No, and I don't know what those are    Yes, somewhat
# 9902                No, and I don't know what those are          Neutral
# 9903                No, and I don't know what those are   No, not really
# 9904                No, and I don't know what those are    Yes, somewhat
# 9905                                                NaN              NaN
#
#                                  WelcomeChange  \
# 0      Just as welcome now as I felt last year
# 1      Just as welcome now as I felt last year
# 2      Just as welcome now as I felt last year
# 3      Just as welcome now as I felt last year
# 4      Just as welcome now as I felt last year
# ...                                        ...
# 9901   Just as welcome now as I felt last year
# 9902   Just as welcome now as I felt last year
# 9903   Just as welcome now as I felt last year
# 9904  Somewhat more welcome now than last year
# 9905                                       NaN
#
#                                            SONewContent   Age Gender Trans  \
# 0     Tech articles written by other developers;Indu...  14.0    Man    No
# 1     Tech articles written by other developers;Indu...  19.0    Man    No
# 2     Tech meetups or events in your area;Courses on...  28.0    Man    No
# 3     Tech articles written by other developers;Indu...  22.0    Man    No
# 4     Tech meetups or events in your area;Courses on...  30.0    Man    No
# ...                                                 ...   ...    ...   ...
# 9901  Tech articles written by other developers;Indu...  24.0    Man    No
# 9902  Tech articles written by other developers;Indu...  28.0    Man    No
# 9903  Tech articles written by other developers;Indu...  21.0    Man    No
# 9904          Tech articles written by other developers  23.0    Man    No
# 9905                                                NaN   NaN    NaN   NaN
#
#                     Sexuality                                 Ethnicity  \
# 0     Straight / Heterosexual                                       NaN
# 1     Straight / Heterosexual                                       NaN
# 2     Straight / Heterosexual                                       NaN
# 3     Straight / Heterosexual              White or of European descent
# 4     Straight / Heterosexual  White or of European descent;Multiracial
# ...                       ...                                       ...
# 9901  Straight / Heterosexual              White or of European descent
# 9902                      NaN                                       NaN
# 9903  Straight / Heterosexual              White or of European descent
# 9904  Straight / Heterosexual              White or of European descent
# 9905                      NaN                                       NaN
#
#      Dependents           SurveyLength                  SurveyEase
# 0            No  Appropriate in length  Neither easy nor difficult
# 1            No  Appropriate in length  Neither easy nor difficult
# 2           Yes  Appropriate in length  Neither easy nor difficult
# 3            No  Appropriate in length                        Easy
# 4            No  Appropriate in length                        Easy
# ...         ...                    ...                         ...
# 9901         No               Too long                   Difficult
# 9902        Yes               Too long  Neither easy nor difficult
# 9903         No  Appropriate in length                        Easy
# 9904         No  Appropriate in length  Neither easy nor difficult
# 9905        NaN                    NaN                         NaN
#
# [9906 rows x 85 columns]

# %%
#updating the name of the column
df.rename(columns = {'ConvertedComp': 'Salary[USD $]'}, inplace = True)

# %%
df['Salary[USD $]']
# Out:
# 0            NaN
# 1            NaN
# 2         8820.0
# 3        61000.0
# 4            NaN
#           ...
# 9901     27696.0
# 9902         NaN
# 9903         NaN
# 9904     75000.0
# 9905    117000.0
# Name: Salary[USD $], Length: 9906, dtype: float64

# %%
df['Hobbyist']
# Out:
# 0       Yes
# 1        No
# 2       Yes
# 3        No
# 4       Yes
#        ...
# 9901    Yes
# 9902    Yes
# 9903    Yes
# 9904     No
# 9905    Yes
# Name: Hobbyist, Length: 9906, dtype: object

# %%
# map is used to substitute values
#for each yes convert it to True and so on....

df['Hobbyist'].map({'Yes':True,'No':False})
# Out:
# 0        True
# 1       False
# 2        True
# 3       False
# 4        True
#         ...
# 9901     True
# 9902     True
# 9903     True
# 9904    False
# 9905     True
# Name: Hobbyist, Length: 9906, dtype: bool

# %%
df['Hobbyist'] = df['Hobbyist'].map({'Yes':True,'No':False})

# %%
df
# Out:
#       Respondent                                         MainBranch  Hobbyist  \
# 0              1             I am a student who is learning to code      True
# 1              2             I am a student who is learning to code     False
# 2              3  I am not primarily a developer, but I write co...      True
# 3              4                     I am a developer by profession     False
# 4              5                     I am a developer by profession      True
# ...          ...                                                ...       ...
# 9901        9943                     I am a developer by profession      True
# 9902        9944                     I am a developer by profession      True
# 9903        9945             I am a student who is learning to code      True
# 9904        9946                     I am a developer by profession     False
# 9905        9947                     I am a developer by profession      True
#
#                                             OpenSourcer  \
# 0                                                 Never
# 1                               Less than once per year
# 2                                                 Never
# 3                                                 Never
# 4                            Once a month or more often
# ...                                                 ...
# 9901                                              Never
# 9902                            Less than once per year
# 9903  Less than once a month but more than once per ...
# 9904  Less than once a month but more than once per ...
# 9905                            Less than once per year
#
#                                              OpenSource  \
# 0     The quality of OSS and closed source software ...
# 1     The quality of OSS and closed source software ...
# 2     The quality of OSS and closed source software ...
# 3     The quality of OSS and closed source software ...
# 4     OSS is, on average, of HIGHER quality than pro...
# ...                                                 ...
# 9901  OSS is, on average, of HIGHER quality than pro...
# 9902  The quality of OSS and closed source software ...
# 9903  The quality of OSS and closed source software ...
# 9904  OSS is, on average, of HIGHER quality than pro...
# 9905  OSS is, on average, of HIGHER quality than pro...
#
#                                   Employment                 Country  \
# 0     Not employed, and not looking for work          United Kingdom
# 1         Not employed, but looking for work  Bosnia and Herzegovina
# 2                         Employed full-time                Thailand
# 3                         Employed full-time           United States
# 4                         Employed full-time                 Ukraine
# ...                                      ...                     ...
# 9901                      Employed full-time                 Ukraine
# 9902                      Employed full-time                   India
# 9903                      Employed part-time           United States
# 9904                      Employed full-time           United States
# 9905                      Employed full-time           United States
#
#              Student                                            EdLevel  \
# 0                 No                          Primary/elementary school
# 1     Yes, full-time  Secondary school (e.g. American high school, G...
# 2                 No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 3                 No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4                 No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# ...              ...                                                ...
# 9901  Yes, full-time        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 9902             NaN           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 9903  Yes, full-time                                   Associate degree
# 9904              No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 9905              No           Bachelor’s degree (BA, BS, B.Eng., etc.)
#
#                                          UndergradMajor  \
# 0                                                   NaN
# 1                                                   NaN
# 2                         Web development or web design
# 3     Computer science, computer engineering, or sof...
# 4     Computer science, computer engineering, or sof...
# ...                                                 ...
# 9901  Computer science, computer engineering, or sof...
# 9902  Information systems, information technology, o...
# 9903  Computer science, computer engineering, or sof...
# 9904  Computer science, computer engineering, or sof...
# 9905  Another engineering discipline (ex. civil, ele...
#
#                                                EduOther  \
# 0     Taught yourself a new language, framework, or ...
# 1     Taken an online course in programming or softw...
# 2     Taught yourself a new language, framework, or ...
# 3     Taken an online course in programming or softw...
# 4     Taken an online course in programming or softw...
# ...                                                 ...
# 9901  Taken an online course in programming or softw...
# 9902  Taken an online course in programming or softw...
# 9903  Taken an online course in programming or softw...
# 9904  Taught yourself a new language, framework, or ...
# 9905  Taught yourself a new language, framework, or ...
#
#                        OrgSize  \
# 0                          NaN
# 1                          NaN
# 2         100 to 499 employees
# 3         100 to 499 employees
# 4     10,000 or more employees
# ...                        ...
# 9901        20 to 99 employees
# 9902  10,000 or more employees
# 9903                       NaN
# 9904      500 to 999 employees
# 9905  1,000 to 4,999 employees
#
#                                                 DevType YearsCode Age1stCode  \
# 0                                                   NaN         4         10
# 1     Developer, desktop or enterprise applications;...       NaN         17
# 2     Designer;Developer, back-end;Developer, front-...         3         22
# 3                                 Developer, full-stack         3         16
# 4     Academic researcher;Developer, desktop or ente...        16         14
# ...                                                 ...       ...        ...
# 9901                                Developer, back-end         9         15
# 9902  Developer, back-end;Developer, desktop or ente...         4         20
# 9903  Developer, back-end;Developer, front-end;Devel...         6         14
# 9904  Developer, embedded applications or devices;De...         8         15
# 9905  Developer, back-end;Developer, front-end;Devel...        22          9
#
#           YearsCodePro              CareerSat  \
# 0                  NaN                    NaN
# 1                  NaN                    NaN
# 2                    1     Slightly satisfied
# 3     Less than 1 year         Very satisfied
# 4                    9      Very dissatisfied
# ...                ...                    ...
# 9901                 4     Slightly satisfied
# 9902                 4  Slightly dissatisfied
# 9903               NaN                    NaN
# 9904                 2     Slightly satisfied
# 9905                10         Very satisfied
#
#                                   JobSat              MgrIdiot  MgrMoney  \
# 0                                    NaN                   NaN       NaN
# 1                                    NaN                   NaN       NaN
# 2                     Slightly satisfied  Not at all confident  Not sure
# 3                     Slightly satisfied        Very confident        No
# 4                  Slightly dissatisfied    Somewhat confident       Yes
# ...                                  ...                   ...       ...
# 9901                  Slightly satisfied        Very confident  Not sure
# 9902  Neither satisfied nor dissatisfied    Somewhat confident  Not sure
# 9903                                 NaN                   NaN       NaN
# 9904  Neither satisfied nor dissatisfied        Very confident  Not sure
# 9905                      Very satisfied        Very confident       Yes
#
#        MgrWant                                            JobSeek  \
# 0          NaN                                                NaN
# 1          NaN                    I am actively looking for a job
# 2     Not sure  I’m not actively looking, but I am open to new...
# 3     Not sure       I am not interested in new job opportunities
# 4           No       I am not interested in new job opportunities
# ...        ...                                                ...
# 9901       Yes       I am not interested in new job opportunities
# 9902       Yes                    I am actively looking for a job
# 9903       NaN  I’m not actively looking, but I am open to new...
# 9904       Yes                    I am actively looking for a job
# 9905        No  I’m not actively looking, but I am open to new...
#
#                LastHireDate  \
# 0                       NaN
# 1      I've never had a job
# 2             1-2 years ago
# 3      Less than a year ago
# 4      Less than a year ago
# ...                     ...
# 9901   Less than a year ago
# 9902          1-2 years ago
# 9903   Less than a year ago
# 9904          1-2 years ago
# 9905  More than 4 years ago
#
#                                                 LastInt FizzBuzz  \
# 0                                                   NaN      NaN
# 1                                                   NaN      NaN
# 2                   Interview with people in peer roles       No
# 3     Write code by hand (e.g., on a whiteboard);Int...       No
# 4     Write any code;Write code by hand (e.g., on a ...       No
# ...                                                 ...      ...
# 9901  Interview with people in peer roles;Interview ...      Yes
# 9902         Write code by hand (e.g., on a whiteboard)       No
# 9903                                                NaN      NaN
# 9904  Write any code;Interview with people in peer r...       No
# 9905  Write any code;Write code by hand (e.g., on a ...       No
#
#                                              JobFactors  \
# 0                                                   NaN
# 1     Financial performance or funding status of the...
# 2     Languages, frameworks, and other technologies ...
# 3     Languages, frameworks, and other technologies ...
# 4     Industry that I'd be working in;Languages, fra...
# ...                                                 ...
# 9901  Languages, frameworks, and other technologies ...
# 9902  Languages, frameworks, and other technologies ...
# 9903  Specific department or team I'd be working on;...
# 9904  Languages, frameworks, and other technologies ...
# 9905  Financial performance or funding status of the...
#
#                                            ResumeUpdate CurrencySymbol  \
# 0                                                   NaN            NaN
# 1     Something else changed (education, award, medi...            NaN
# 2                      I was preparing for a job search            THB
# 3                      I was preparing for a job search            USD
# 4                      I was preparing for a job search            UAH
# ...                                                 ...            ...
# 9901   My job status changed (promotion, new job, etc.)            UAH
# 9902                   I was preparing for a job search            INR
# 9903   My job status changed (promotion, new job, etc.)            NaN
# 9904                   I was preparing for a job search            USD
# 9905  Something else changed (education, award, medi...            USD
#
#               CurrencyDesc  CompTotal CompFreq  Salary[USD $]  WorkWeekHrs  \
# 0                      NaN        NaN      NaN            NaN          NaN
# 1                      NaN        NaN      NaN            NaN          NaN
# 2                Thai baht    23000.0  Monthly         8820.0         40.0
# 3     United States dollar    61000.0   Yearly        61000.0         80.0
# 4        Ukrainian hryvnia        NaN      NaN            NaN         55.0
# ...                    ...        ...      ...            ...          ...
# 9901     Ukrainian hryvnia    64000.0  Monthly        27696.0         40.0
# 9902          Indian rupee        NaN  Monthly            NaN         40.0
# 9903                   NaN        NaN      NaN            NaN          NaN
# 9904  United States dollar    75000.0   Yearly        75000.0         35.0
# 9905  United States dollar   117000.0   Yearly       117000.0         45.0
#
#                                                WorkPlan  \
# 0                                                   NaN
# 1                                                   NaN
# 2     There's no schedule or spec; I work on what se...
# 3     There's no schedule or spec; I work on what se...
# 4     There is a schedule and/or spec (made by me or...
# ...                                                 ...
# 9901  There's no schedule or spec; I work on what se...
# 9902  There's no schedule or spec; I work on what se...
# 9903                                                NaN
# 9904  There is a schedule and/or spec (made by me or...
# 9905  There is a schedule and/or spec (made by me or...
#
#                                           WorkChallenge  \
# 0                                                   NaN
# 1                                                   NaN
# 2     Distracting work environment;Inadequate access...
# 3                                                   NaN
# 4     Being tasked with non-development work;Inadequ...
# ...                                                 ...
# 9901  Distracting work environment;Lack of support f...
# 9902             Being tasked with non-development work
# 9903                                                NaN
# 9904  Inadequate access to necessary tools;Meetings;...
# 9905  Being tasked with non-development work;Distrac...
#
#                                              WorkRemote WorkLoc  \
# 0                                                   NaN     NaN
# 1                                                   NaN     NaN
# 2                      Less than once per month / Never    Home
# 3                      Less than once per month / Never    Home
# 4                                 A few days each month  Office
# ...                                                 ...     ...
# 9901                   Less than once per month / Never  Office
# 9902              More than half, but not all, the time  Office
# 9903                                                NaN     NaN
# 9904  All or almost all the time (I'm full-time remote)  Office
# 9905                              A few days each month  Office
#
#                       ImpSyn                                  CodeRev  \
# 0                        NaN                                      NaN
# 1                        NaN                                      NaN
# 2                    Average                                       No
# 3     A little below average                                       No
# 4     A little above average  Yes, because I see value in code review
# ...                      ...                                      ...
# 9901                 Average  Yes, because I see value in code review
# 9902       Far above average  Yes, because I see value in code review
# 9903                     NaN                                      NaN
# 9904       Far above average  Yes, because I see value in code review
# 9905                 Average  Yes, because I see value in code review
#
#       CodeRevHrs                                          UnitTests  \
# 0            NaN                                                NaN
# 1            NaN                                                NaN
# 2            NaN                          No, but I think we should
# 3            NaN                          No, but I think we should
# 4            NaN                      Yes, it's part of our process
# ...          ...                                                ...
# 9901        10.0                      Yes, it's part of our process
# 9902         5.0                      Yes, it's part of our process
# 9903         NaN                                                NaN
# 9904         2.0                          No, but I think we should
# 9905         5.0  Yes, it's not part of our process but the deve...
#
#                                             PurchaseHow  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                              Not sure
# 3     Developers typically have the most influence o...
# 4                                              Not sure
# ...                                                 ...
# 9901                                           Not sure
# 9902                                           Not sure
# 9903                                                NaN
# 9904  Developers and management have nearly equal in...
# 9905                                           Not sure
#
#                           PurchaseWhat  \
# 0                                  NaN
# 1                                  NaN
# 2        I have little or no influence
# 3        I have little or no influence
# 4        I have little or no influence
# ...                                ...
# 9901             I have some influence
# 9902     I have little or no influence
# 9903                               NaN
# 9904  I have a great deal of influence
# 9905     I have little or no influence
#
#                                      LanguageWorkedWith  \
# 0                       HTML/CSS;Java;JavaScript;Python
# 1                                   C++;HTML/CSS;Python
# 2                                              HTML/CSS
# 3                                   C;C++;C#;Python;SQL
# 4           C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
# ...                                                 ...
# 9901  Bash/Shell/PowerShell;HTML/CSS;JavaScript;PHP;SQL
# 9902                                Java;JavaScript;SQL
# 9903     C++;C#;HTML/CSS;Java;JavaScript;SQL;TypeScript
# 9904                                               C;C#
# 9905                         Java;JavaScript;Kotlin;SQL
#
#                                  LanguageDesireNextYear  \
# 0       C;C++;C#;Go;HTML/CSS;Java;JavaScript;Python;SQL
# 1                           C++;HTML/CSS;JavaScript;SQL
# 2                                       Elixir;HTML/CSS
# 3                                   C;C#;JavaScript;SQL
# 4              HTML/CSS;Java;JavaScript;SQL;WebAssembly
# ...                                                 ...
# 9901  Bash/Shell/PowerShell;HTML/CSS;JavaScript;PHP;SQL
# 9902                          Java;JavaScript;Other(s):
# 9903              C#;HTML/CSS;JavaScript;SQL;TypeScript
# 9904                                 C#;Rust;TypeScript
# 9905                    C++;Erlang;Go;JavaScript;Kotlin
#
#                                     DatabaseWorkedWith  \
# 0                                               SQLite
# 1                                                  NaN
# 2                                           PostgreSQL
# 3                                         MySQL;SQLite
# 4     Couchbase;MongoDB;MySQL;Oracle;PostgreSQL;SQLite
# ...                                                ...
# 9901                               MongoDB;MySQL;Redis
# 9902                                             MySQL
# 9903                 Microsoft SQL Server;MySQL;SQLite
# 9904                                             MySQL
# 9905                       Microsoft SQL Server;SQLite
#
#                                  DatabaseDesireNextYear  \
# 0                                                 MySQL
# 1                                                 MySQL
# 2                                            PostgreSQL
# 3                                          MySQL;SQLite
# 4     Couchbase;Firebase;MongoDB;MySQL;Oracle;Postgr...
# ...                                                 ...
# 9901                                MongoDB;MySQL;Redis
# 9902                                      MongoDB;MySQL
# 9903                  Microsoft SQL Server;MySQL;SQLite
# 9904                             DynamoDB;MongoDB;MySQL
# 9905                                                NaN
#
#                      PlatformWorkedWith  \
# 0                         MacOS;Windows
# 1                               Windows
# 2                                   NaN
# 3                         Linux;Windows
# 4     Android;Linux;MacOS;Slack;Windows
# ...                                 ...
# 9901                       Docker;Linux
# 9902                  AWS;Linux;Windows
# 9903                                NaN
# 9904                        Android;iOS
# 9905                            Android
#
#                        PlatformDesireNextYear  \
# 0                     Android;Arduino;Windows
# 1                                     Windows
# 2                                         NaN
# 3                               Linux;Windows
# 4       Android;Docker;Kubernetes;Linux;Slack
# ...                                       ...
# 9901                             Docker;Linux
# 9902  AWS;Google Cloud Platform;Linux;Windows
# 9903                                      NaN
# 9904    Android;Docker;iOS;Raspberry Pi;Slack
# 9905  Android;Arduino;AWS;Docker;Raspberry Pi
#
#                                WebFrameWorkedWith  \
# 0                                    Django;Flask
# 1                                          Django
# 2                                             NaN
# 3                                             NaN
# 4     Django;Express;Flask;jQuery;React.js;Spring
# ...                                           ...
# 9901                             jQuery;Other(s):
# 9902                                       jQuery
# 9903            Angular/Angular.js;ASP.NET;jQuery
# 9904                                          NaN
# 9905                                     React.js
#
#                  WebFrameDesireNextYear               MiscTechWorkedWith  \
# 0                          Flask;jQuery                          Node.js
# 1                                Django                              NaN
# 2                             Other(s):                              NaN
# 3                                   NaN                             .NET
# 4          Flask;jQuery;React.js;Spring                  Cordova;Node.js
# ...                                 ...                              ...
# 9901                 React.js;Other(s):                              NaN
# 9902              Express;jQuery;Spring                              NaN
# 9903  Angular/Angular.js;ASP.NET;jQuery           .NET;.NET Core;Node.js
# 9904     ASP.NET;React.js;Spring;Vue.js  .NET;.NET Core;Unity 3D;Xamarin
# 9905                           React.js                     React Native
#
#                            MiscTechDesireNextYear  \
# 0                                         Node.js
# 1                                             NaN
# 2                                             NaN
# 3                                            .NET
# 4        Apache Spark;Hadoop;Node.js;React Native
# ...                                           ...
# 9901                                      Node.js
# 9902                              Ansible;Node.js
# 9903                            .NET Core;Node.js
# 9904  Flutter;.NET;.NET Core;React Native;Xamarin
# 9905                                 React Native
#
#                                         DevEnviron        OpSys  \
# 0                       IntelliJ;Notepad++;PyCharm      Windows
# 1                                     Atom;PyCharm      Windows
# 2                           Vim;Visual Studio Code  Linux-based
# 3     Eclipse;Vim;Visual Studio;Visual Studio Code      Windows
# 4                           IntelliJ;Notepad++;Vim  Linux-based
# ...                                            ...          ...
# 9901                                      PHPStorm  Linux-based
# 9902            Eclipse;PyCharm;Visual Studio Code      Windows
# 9903    Notepad++;Visual Studio;Visual Studio Code      Windows
# 9904              Visual Studio;Visual Studio Code      Windows
# 9905      Android Studio;IntelliJ;Sublime Text;Vim        MacOS
#
#                                              Containers BlockchainOrg  \
# 0                               I do not use containers           NaN
# 1                               I do not use containers           NaN
# 2                               I do not use containers           NaN
# 3                               I do not use containers    Not at all
# 4                Outside of work, for personal projects    Not at all
# ...                                                 ...           ...
# 9901  Development;Outside of work, for personal proj...           NaN
# 9902                            I do not use containers           NaN
# 9903                            I do not use containers           NaN
# 9904                                                NaN    Not at all
# 9905                            I do not use containers    Not at all
#
#                                            BlockchainIs BetterLife  \
# 0                                                   NaN        Yes
# 1     Useful across many domains and could change ma...        Yes
# 2                                                   NaN        Yes
# 3     Useful for decentralized currency (i.e., Bitcoin)        Yes
# 4                                                   NaN        Yes
# ...                                                 ...        ...
# 9901                                                NaN        Yes
# 9902                                                NaN        Yes
# 9903                                                NaN         No
# 9904                                      A passing fad        Yes
# 9905                                                 An        NaN
#
#                                       ITperson  OffOn SocialMedia  \
# 0     Fortunately, someone else has that title    Yes     Twitter
# 1                                          Yes    Yes   Instagram
# 2                                          Yes    Yes      Reddit
# 3                                         SIGH    Yes      Reddit
# 4                                     Also Yes    Yes    Facebook
# ...                                        ...    ...         ...
# 9901                                       Yes  What?     YouTube
# 9902                                       Yes  What?   Instagram
# 9903                                  Also Yes     No     Twitter
# 9904                                  Also Yes    Yes     YouTube
# 9905                                       NaN    NaN         NaN
#
#                   Extraversion ScreenName        SOVisit1st  \
# 0                       Online   Username              2017
# 1                       Online   Username              2017
# 2     In real life (in person)   Username              2011
# 3     In real life (in person)   Username              2014
# 4     In real life (in person)   Username  I don't remember
# ...                        ...        ...               ...
# 9901  In real life (in person)   Username              2013
# 9902  In real life (in person)      Login              2013
# 9903                    Online   Username              2014
# 9904  In real life (in person)      Login  I don't remember
# 9905                       NaN        NaN               NaN
#
#                           SOVisitFreq  \
# 0     A few times per month or weekly
# 1               Daily or almost daily
# 2                A few times per week
# 3               Daily or almost daily
# 4              Multiple times per day
# ...                               ...
# 9901           Multiple times per day
# 9902           Multiple times per day
# 9903            Daily or almost daily
# 9904            Daily or almost daily
# 9905                              NaN
#
#                                               SOVisitTo  \
# 0     Find answers to specific questions;Learn how t...
# 1     Find answers to specific questions;Learn how t...
# 2     Find answers to specific questions;Learn how t...
# 3     Find answers to specific questions;Pass the ti...
# 4                    Find answers to specific questions
# ...                                                 ...
# 9901  Find answers to specific questions;Learn how t...
# 9902                 Find answers to specific questions
# 9903  Find answers to specific questions;Learn how t...
# 9904                 Find answers to specific questions
# 9905                                                NaN
#
#                      SOFindAnswer                         SOTimeSaved  \
# 0              3-5 times per week      Stack Overflow was much faster
# 1              3-5 times per week      Stack Overflow was much faster
# 2             6-10 times per week            They were about the same
# 3              1-2 times per week      Stack Overflow was much faster
# 4     More than 10 times per week      Stack Overflow was much faster
# ...                           ...                                 ...
# 9901          6-10 times per week      Stack Overflow was much faster
# 9902           3-5 times per week  Stack Overflow was slightly faster
# 9903           3-5 times per week  Stack Overflow was slightly faster
# 9904           1-2 times per week      Stack Overflow was much faster
# 9905                          NaN                                 NaN
#
#       SOHowMuchTime                  SOAccount  \
# 0     31-60 minutes                         No
# 1     11-30 minutes                        Yes
# 2               NaN                        Yes
# 3     31-60 minutes                        Yes
# 4               NaN                        Yes
# ...             ...                        ...
# 9901   0-10 minutes                        Yes
# 9902    60+ minutes                        Yes
# 9903  11-30 minutes  Not sure / can't remember
# 9904    60+ minutes                        Yes
# 9905            NaN                        NaN
#
#                                              SOPartFreq  \
# 0                                                   NaN
# 1                       A few times per month or weekly
# 2                   Less than once per month or monthly
# 3                   Less than once per month or monthly
# 4                       A few times per month or weekly
# ...                                                 ...
# 9901                Less than once per month or monthly
# 9902  I have never participated in Q&A on Stack Over...
# 9903                                                NaN
# 9904  I have never participated in Q&A on Stack Over...
# 9905                                                NaN
#
#                                                  SOJobs  \
# 0     No, I didn't know that Stack Overflow had a jo...
# 1     No, I knew that Stack Overflow had a job board...
# 2                                                   Yes
# 3                                                   Yes
# 4     No, I knew that Stack Overflow had a job board...
# ...                                                 ...
# 9901  No, I knew that Stack Overflow had a job board...
# 9902  No, I didn't know that Stack Overflow had a jo...
# 9903  No, I didn't know that Stack Overflow had a jo...
# 9904                                                Yes
# 9905                                                NaN
#
#                                                EntTeams           SOComm  \
# 0                   No, and I don't know what those are          Neutral
# 1                   No, and I don't know what those are    Yes, somewhat
# 2     No, I've heard of them, but I am not part of a...          Neutral
# 3                   No, and I don't know what those are   No, not really
# 4     No, I've heard of them, but I am not part of a...  Yes, definitely
# ...                                                 ...              ...
# 9901                No, and I don't know what those are    Yes, somewhat
# 9902                No, and I don't know what those are          Neutral
# 9903                No, and I don't know what those are   No, not really
# 9904                No, and I don't know what those are    Yes, somewhat
# 9905                                                NaN              NaN
#
#                                  WelcomeChange  \
# 0      Just as welcome now as I felt last year
# 1      Just as welcome now as I felt last year
# 2      Just as welcome now as I felt last year
# 3      Just as welcome now as I felt last year
# 4      Just as welcome now as I felt last year
# ...                                        ...
# 9901   Just as welcome now as I felt last year
# 9902   Just as welcome now as I felt last year
# 9903   Just as welcome now as I felt last year
# 9904  Somewhat more welcome now than last year
# 9905                                       NaN
#
#                                            SONewContent   Age Gender Trans  \
# 0     Tech articles written by other developers;Indu...  14.0    Man    No
# 1     Tech articles written by other developers;Indu...  19.0    Man    No
# 2     Tech meetups or events in your area;Courses on...  28.0    Man    No
# 3     Tech articles written by other developers;Indu...  22.0    Man    No
# 4     Tech meetups or events in your area;Courses on...  30.0    Man    No
# ...                                                 ...   ...    ...   ...
# 9901  Tech articles written by other developers;Indu...  24.0    Man    No
# 9902  Tech articles written by other developers;Indu...  28.0    Man    No
# 9903  Tech articles written by other developers;Indu...  21.0    Man    No
# 9904          Tech articles written by other developers  23.0    Man    No
# 9905                                                NaN   NaN    NaN   NaN
#
#                     Sexuality                                 Ethnicity  \
# 0     Straight / Heterosexual                                       NaN
# 1     Straight / Heterosexual                                       NaN
# 2     Straight / Heterosexual                                       NaN
# 3     Straight / Heterosexual              White or of European descent
# 4     Straight / Heterosexual  White or of European descent;Multiracial
# ...                       ...                                       ...
# 9901  Straight / Heterosexual              White or of European descent
# 9902                      NaN                                       NaN
# 9903  Straight / Heterosexual              White or of European descent
# 9904  Straight / Heterosexual              White or of European descent
# 9905                      NaN                                       NaN
#
#      Dependents           SurveyLength                  SurveyEase
# 0            No  Appropriate in length  Neither easy nor difficult
# 1            No  Appropriate in length  Neither easy nor difficult
# 2           Yes  Appropriate in length  Neither easy nor difficult
# 3            No  Appropriate in length                        Easy
# 4            No  Appropriate in length                        Easy
# ...         ...                    ...                         ...
# 9901         No               Too long                   Difficult
# 9902        Yes               Too long  Neither easy nor difficult
# 9903         No  Appropriate in length                        Easy
# 9904         No  Appropriate in length  Neither easy nor difficult
# 9905        NaN                    NaN                         NaN
#
# [9906 rows x 85 columns]
