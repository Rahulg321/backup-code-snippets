# %%
import pandas as pd

# %%
people = {
    'name':['Rahul','Surbhi','Ekta'],
    'last_name':['Gupta','Bhandari','Sadana'],
    'email':['rahul.gupta@gmail.com','surbhi.bhandari@gmail.com','ekta.sadana@gmail.com']
}

# %%
people_df = pd.DataFrame(people)

# %%
people_df
# Out:
#      name last_name                      email
# 0   Rahul     Gupta      rahul.gupta@gmail.com
# 1  Surbhi  Bhandari  surbhi.bhandari@gmail.com
# 2    Ekta    Sadana      ekta.sadana@gmail.com

# %%
people_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   name       3 non-null      object
#  1   last_name  3 non-null      object
#  2   email      3 non-null      object
# dtypes: object(3)
# memory usage: 200.0+ bytes

# %%
people_df
# Out:
#      name last_name                      email
# 0   Rahul     Gupta      rahul.gupta@gmail.com
# 1  Surbhi  Bhandari  surbhi.bhandari@gmail.com
# 2    Ekta    Sadana      ekta.sadana@gmail.com

# %%
people_df['email']
# Out:
# 0        rahul.gupta@gmail.com
# 1    surbhi.bhandari@gmail.com
# 2        ekta.sadana@gmail.com
# Name: email, dtype: object

# %%
people_df[['last_name','email']]
# Out:
#   last_name                      email
# 0     Gupta      rahul.gupta@gmail.com
# 1  Bhandari  surbhi.bhandari@gmail.com
# 2    Sadana      ekta.sadana@gmail.com

# %%
people_df.columns
# Out:
# Index(['name', 'last_name', 'email'], dtype='object')

# %%
#loc and iloc
people_df.iloc[[0,1]] #will return the full first and second row
# people_df.iloc[0,1]  will return one single object
# Out:
#      name last_name                      email
# 0   Rahul     Gupta      rahul.gupta@gmail.com
# 1  Surbhi  Bhandari  surbhi.bhandari@gmail.com

# %%
people_df.iloc[[0,1],[1,2]]
#               rows  columns
# Out:
#   last_name                      email
# 0     Gupta      rahul.gupta@gmail.com
# 1  Bhandari  surbhi.bhandari@gmail.com

# %%
people_df
# Out:
#      name last_name                      email
# 0   Rahul     Gupta      rahul.gupta@gmail.com
# 1  Surbhi  Bhandari  surbhi.bhandari@gmail.com
# 2    Ekta    Sadana      ekta.sadana@gmail.com

# %%
people_df.iloc[1,1] = 'Gupta'   #this change is an inplace change

# %%
people_df
# Out:
#      name last_name                      email
# 0   Rahul     Gupta      rahul.gupta@gmail.com
# 1  Surbhi     Gupta  surbhi.bhandari@gmail.com
# 2    Ekta    Sadana      ekta.sadana@gmail.com

# %%
people_df['last_name'].value_counts()
# Out:
# Gupta     2
# Sadana    1
# Name: last_name, dtype: int64

# %%
people_df.loc[0:1,'last_name':'email']   #slicing with loc
# Out:
#   last_name                      email
# 0     Gupta      rahul.gupta@gmail.com
# 1     Gupta  surbhi.bhandari@gmail.com

# %%
people_df
# Out:
#      name last_name                      email
# 0   Rahul     Gupta      rahul.gupta@gmail.com
# 1  Surbhi     Gupta  surbhi.bhandari@gmail.com
# 2    Ekta    Sadana      ekta.sadana@gmail.com

# %%
people_df.iloc[0:2]  #with iloc last value is exclusive
# Out:
#      name last_name                      email
# 0   Rahul     Gupta      rahul.gupta@gmail.com
# 1  Surbhi     Gupta  surbhi.bhandari@gmail.com

# %%
people_df
# Out:
#      name last_name                      email
# 0   Rahul     Gupta      rahul.gupta@gmail.com
# 1  Surbhi     Gupta  surbhi.bhandari@gmail.com
# 2    Ekta    Sadana      ekta.sadana@gmail.com

# %%
#setting index
# people_df.set_index('name')
people_df.set_index('name', inplace = True)

# %%
people_df
# Out:
#        last_name                      email
# name
# Rahul      Gupta      rahul.gupta@gmail.com
# Surbhi     Gupta  surbhi.bhandari@gmail.com
# Ekta      Sadana      ekta.sadana@gmail.com

# %%
# people_df.loc['Rahul']
people_df.loc['Ekta','last_name']
# Out:
# 'Sadana'

# %%
people_df.reset_index(inplace = True)

# %%
people_df
# Out:
#      name last_name                      email
# 0   Rahul     Gupta      rahul.gupta@gmail.com
# 1  Surbhi     Gupta  surbhi.bhandari@gmail.com
# 2    Ekta    Sadana      ekta.sadana@gmail.com

# %%
people_df.set_index('name', inplace = True)

# %%
#sorting the index alphabetically
people_df = people_df.sort_index()

# %%
people_df
# Out:
#        last_name                      email
# name
# Ekta      Sadana      ekta.sadana@gmail.com
# Rahul      Gupta      rahul.gupta@gmail.com
# Surbhi     Gupta  surbhi.bhandari@gmail.com

# %%
#filtering data and applying filters
filt = (people_df['last_name'] == 'Gupta') & (people_df['last_name'] == 'Sadana')

# %%
people_df[~filt]
people_df[filt]
# Out:
# Empty DataFrame
# Columns: [last_name, email]
# Index: []

# %%
people_df
# Out:
#        last_name                      email
# name
# Ekta      Sadana      ekta.sadana@gmail.com
# Rahul      Gupta      rahul.gupta@gmail.com
# Surbhi     Gupta  surbhi.bhandari@gmail.com

# %%
names = ['Sharma','Sadana','Bhandari','Gupta']

last_name_filter = (people_df['last_name'].isin(names))

people_df[last_name_filter]
# Out:
#        last_name                      email
# name
# Ekta      Sadana      ekta.sadana@gmail.com
# Rahul      Gupta      rahul.gupta@gmail.com
# Surbhi     Gupta  surbhi.bhandari@gmail.com

# %%
people_df.loc['Surbhi','email'] = 'surbhi.bhandari@yahoo.com'

# %%
people_df
# Out:
#        last_name                      email
# name
# Ekta      Sadana      ekta.sadana@gmail.com
# Rahul      Gupta      rahul.gupta@gmail.com
# Surbhi     Gupta  surbhi.bhandari@yahoo.com

# %%
gmail_filter = (people_df['email'].str.contains('gmail', na = False))

# %%
people_df.loc[gmail_filter,'last_name']
# Out:
# name
# Ekta     Sadana
# Rahul     Gupta
# Name: last_name, dtype: object

# %%
people_df
# Out:
#        last_name                      email
# name
# Ekta      Sadana      ekta.sadana@gmail.com
# Rahul      Gupta      rahul.gupta@gmail.com
# Surbhi     Gupta  surbhi.bhandari@yahoo.com

# %%
people_df.columns
# Out:
# Index(['last_name', 'email'], dtype='object')

# %%
people_df.columns = ['LAST_NAME','EMAIL_ID']

# %%
people_df.reset_index(inplace = True)

# %%
people_df
# Out:
#      name LAST_NAME                   EMAIL_ID
# 0    Ekta    Sadana      ekta.sadana@gmail.com
# 1   Rahul     Gupta      rahul.gupta@gmail.com
# 2  Surbhi     Gupta  surbhi.bhandari@yahoo.com

# %%
people_df.columns = [x.lower() for x in people_df.columns]

# %%
people_df
# Out:
#      name last_name                   email_id
# 0    Ekta    Sadana      ekta.sadana@gmail.com
# 1   Rahul     Gupta      rahul.gupta@gmail.com
# 2  Surbhi     Gupta  surbhi.bhandari@yahoo.com

# %%
people_df.columns = people_df.columns.str.replace('_', ' ')

# %%
people_df
# Out:
#      name last name                   email id
# 0    Ekta    Sadana      ekta.sadana@gmail.com
# 1   Rahul     Gupta      rahul.gupta@gmail.com
# 2  Surbhi     Gupta  surbhi.bhandari@yahoo.com

# %%
people_df.columns = people_df.columns.str.replace(' ', '_')

# %%
people_df
# Out:
#      name last_name                   email_id
# 0    Ekta    Sadana      ekta.sadana@gmail.com
# 1   Rahul     Gupta      rahul.gupta@gmail.com
# 2  Surbhi     Gupta  surbhi.bhandari@yahoo.com

# %%
#updating specific columns

people_df.rename(columns = {'last_name':'Aakhri_Name'}, inplace = True)

# %%
people_df
# Out:
#      name Aakhri_Name                   email_id
# 0    Ekta      Sadana      ekta.sadana@gmail.com
# 1   Rahul       Gupta      rahul.gupta@gmail.com
# 2  Surbhi       Gupta  surbhi.bhandari@yahoo.com

# %%
#added a new row
#if the row exist then it updates and if it doesn't 
#it creates a new row

people_df.loc[3] = ['Karishma','Narula','karishma.narula@gmail.com']

# %%
people_df
# Out:
#        name Aakhri_Name                   email_id
# 0      Ekta      Sadana      ekta.sadana@gmail.com
# 1     Rahul       Gupta      rahul.gupta@gmail.com
# 2    Surbhi       Gupta  surbhi.bhandari@yahoo.com
# 3  Karishma      Narula  karishma.narula@gmail.com

# %%
people_df.rename(columns = {'Aakhri_Name':' last_name'}, inplace = True)

# %%
people_df
# Out:
#        name  last_name                   email_id
# 0      Ekta     Sadana      ekta.sadana@gmail.com
# 1     Rahul      Gupta      rahul.gupta@gmail.com
# 2    Surbhi      Gupta  surbhi.bhandari@yahoo.com
# 3  Karishma     Narula  karishma.narula@gmail.com

# %%
people_df.sort_index()
# Out:
#        name  last_name                   email_id
# 0      Ekta     Sadana      ekta.sadana@gmail.com
# 1     Rahul      Gupta      rahul.gupta@gmail.com
# 2    Surbhi      Gupta  surbhi.bhandari@yahoo.com
# 3  Karishma     Narula  karishma.narula@gmail.com

# %%
people_df['last_name']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /usr/local/lib/python3.8/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.8/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'last_name'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df = pd.DataFrame(people)

# %%
df
# Out:
#      name last_name                      email
# 0   Rahul     Gupta      rahul.gupta@gmail.com
# 1  Surbhi  Bhandari  surbhi.bhandari@gmail.com
# 2    Ekta    Sadana      ekta.sadana@gmail.com

# %%
df['last_name']
# Out:
# 0       Gupta
# 1    Bhandari
# 2      Sadana
# Name: last_name, dtype: object

# %%
df.loc[2]
# Out:
# name                          Ekta
# last_name                   Sadana
# email        ekta.sadana@gmail.com
# Name: 2, dtype: object

# %%
df.loc[2,'last_name'] = 'Sharma'

# %%
df
# Out:
#      name last_name                      email
# 0   Rahul     Gupta      rahul.gupta@gmail.com
# 1  Surbhi  Bhandari  surbhi.bhandari@gmail.com
# 2    Ekta    Sharma      ekta.sadana@gmail.com

# %%
# df.apply(len)
df['email'].apply(len)
# Out:
# 0    21
# 1    25
# 2    21
# Name: email, dtype: int64

# %%
# df.apply(min)
df.apply(pd.Series.min)
# Out:
# name                          Ekta
# last_name                 Bhandari
# email        ekta.sadana@gmail.com
# dtype: object

# %%
df.applymap(str.upper)
# Out:
#      name last_name                      email
# 0   RAHUL     GUPTA      RAHUL.GUPTA@GMAIL.COM
# 1  SURBHI  BHANDARI  SURBHI.BHANDARI@GMAIL.COM
# 2    EKTA    SHARMA      EKTA.SADANA@GMAIL.COM

# %%
df
# Out:
#      name last_name                      email
# 0   Rahul     Gupta      rahul.gupta@gmail.com
# 1  Surbhi  Bhandari  surbhi.bhandari@gmail.com
# 2    Ekta    Sharma      ekta.sadana@gmail.com

# %%
df['name'].replace({'Surbhi':'Karishma'})
# Out:
# 0       Rahul
# 1    Karishma
# 2        Ekta
# Name: name, dtype: object

# %%
df
# Out:
#      name last_name                      email
# 0   Rahul     Gupta      rahul.gupta@gmail.com
# 1  Surbhi  Bhandari  surbhi.bhandari@gmail.com
# 2    Ekta    Sharma      ekta.sadana@gmail.com

# %%
df.apply(min)
# Out:
# name                          Ekta
# last_name                 Bhandari
# email        ekta.sadana@gmail.com
# dtype: object

# %%
df
# Out:
#      name last_name                      email
# 0   Rahul     Gupta      rahul.gupta@gmail.com
# 1  Surbhi  Bhandari  surbhi.bhandari@gmail.com
# 2    Ekta    Sharma      ekta.sadana@gmail.com

# %%
df['full_name'] = df['name'] + ' ' + df['last_name']

# %%
df
# Out:
#      name last_name                      email        full_name
# 0   Rahul     Gupta      rahul.gupta@gmail.com      Rahul Gupta
# 1  Surbhi  Bhandari  surbhi.bhandari@gmail.com  Surbhi Bhandari
# 2    Ekta    Sharma      ekta.sadana@gmail.com      Ekta Sharma

# %%
df.drop(columns = ['name','last_name'], inplace = True)

# %%
df
# Out:
#                        email        full_name
# 0      rahul.gupta@gmail.com      Rahul Gupta
# 1  surbhi.bhandari@gmail.com  Surbhi Bhandari
# 2      ekta.sadana@gmail.com      Ekta Sharma

# %%
df['first_name','last_name'] = df['full_name'].str.split(' ')

# %%
df.drop(columns = [('first_name','last_name')],inplace = True)

# %%
df
# Out:
#                        email        full_name
# 0      rahul.gupta@gmail.com      Rahul Gupta
# 1  surbhi.bhandari@gmail.com  Surbhi Bhandari
# 2      ekta.sadana@gmail.com      Ekta Sharma

# %%
df[['first_name','last_name']] = df['full_name'].str.split(' ', expand = True)

# %%
df
# Out:
#                        email        full_name first_name last_name
# 0      rahul.gupta@gmail.com      Rahul Gupta      Rahul     Gupta
# 1  surbhi.bhandari@gmail.com  Surbhi Bhandari     Surbhi  Bhandari
# 2      ekta.sadana@gmail.com      Ekta Sharma       Ekta    Sharma
# 3                IskiNoEmail              NaN        NaN       NaN

# %%
#removing Rows
df.drop(index = 3,inplace = True)

# %%
df
# Out:
#                        email        full_name first_name last_name
# 0      rahul.gupta@gmail.com      Rahul Gupta      Rahul     Gupta
# 1  surbhi.bhandari@gmail.com  Surbhi Bhandari     Surbhi  Bhandari
# 2      ekta.sadana@gmail.com      Ekta Sharma       Ekta    Sharma

# %%
df = df.append({'first_name':'Tony'}, ignore_index = True)

# %%
df
# Out:
#                        email        full_name first_name last_name
# 0      rahul.gupta@gmail.com      Rahul Gupta      Rahul     Gupta
# 1  surbhi.bhandari@gmail.com  Surbhi Bhandari     Surbhi  Bhandari
# 2      ekta.sadana@gmail.com      Ekta Sharma       Ekta    Sharma
# 3                        NaN              NaN       Tony       NaN

# %%
df.loc[3,'first_name'] = None

# %%
df
# Out:
#                        email        full_name first_name last_name
# 0      rahul.gupta@gmail.com      Rahul Gupta      Rahul     Gupta
# 1  surbhi.bhandari@gmail.com  Surbhi Bhandari     Surbhi  Bhandari
# 2      ekta.sadana@gmail.com      Ekta Sharma       Ekta    Sharma
# 3                        NaN              NaN       None       NaN
