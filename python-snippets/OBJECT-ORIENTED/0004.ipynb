# %%
#learning Inheritance
#creating a sub class

class Employee:

    raise_amt = 1.04
    num_of_emps = 0

    def __init__(self,first,last,pay):
        self.first = first
        self.last = last
        self.pay = pay
        self.email = f'{first}.{last}@company.com'
        Employee.num_of_emps += 1
    
    def full_name(self):
        return f'{self.first} {self.last}'

    def apply_raise(self):
        self.pay = int(self.pay * self.raise_amt)
    
    
class Developer(Employee):
    pass

    
emp_1 = Employee('corey','schafer',154000)
emp_2 = Employee('surbhi','gupta',98000)

dev_3 = Developer('Vanya','arora',84000)

print(help(Developer))
#check the method resolution order
#the order in which inheritance works


# print(emp_1.email)
# print(emp_2.email)


# print(dev_3.email)
# Out:
# Help on class Developer in module __main__:
#
# class Developer(Employee)
#  |  Developer(first, last, pay)
#  |
#  |  Method resolution order:
#  |      Developer
#  |      Employee
#  |      builtins.object
#  |
#  |  Methods inherited from Employee:
#  |
#  |  __init__(self, first, last, pay)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  apply_raise(self)
#  |
#  |  full_name(self)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from Employee:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes inherited from Employee:
#  |
#  |  num_of_emps = 3
#  |
#  |  raise_amt = 1.04
#
# None

# %%
class Employee:

    raise_amt = 1.04
    num_of_emps = 0

    def __init__(self,first,last,pay):
        self.first = first
        self.last = last
        self.pay = pay
        self.email = f'{first}.{last}@company.com'
        Employee.num_of_emps += 1
    
    def full_name(self):
        return f'{self.first} {self.last}'

    def apply_raise(self):
        self.pay = int(self.pay * self.raise_amt)
    

#if we want to change the value of inherited class variable
# for our inherited sub class  
class Developer(Employee):
    raise_amt = 1.10

dev_1 = Developer('Vanya','arora',84000)
dev_2 = Employee('Kashish','singla',10000)

print(dev_1.pay)
dev_1.apply_raise()
print(dev_1.pay)


print(dev_2.pay)
dev_2.apply_raise()
print(dev_2.pay)
# Out:
# 84000
# 92400
# 10000
# 10400

# %%
class Employee:

    raise_amt = 1.04
    num_of_emps = 0

    def __init__(self,first,last,pay):
        self.first = first
        self.last = last
        self.pay = pay
        self.email = f'{first}.{last}@company.com'
        Employee.num_of_emps += 1
    
    def full_name(self):
        return f'{self.first} {self.last}'

    def apply_raise(self):
        self.pay = int(self.pay * self.raise_amt)
    

class Developer(Employee):
    raise_amt = 1.10

    def __init__(self,first,last,pay,prog_lang):
        super().__init__(first,last,pay)
        self.prog_lang = prog_lang

dev_1 = Developer('Vanya','arora',84000,'Python')
dev_2 = Developer('Kashish','singla',10000,'Java')

print(dev_1.email)
print(dev_1.prog_lang)
# Out:
# Vanya.arora@company.com
# Python

# %%
class Employee:

    raise_amt = 1.04
    num_of_emps = 0

    def __init__(self,first,last,pay):
        self.first = first
        self.last = last
        self.pay = pay
        self.email = f'{first}.{last}@company.com'
        Employee.num_of_emps += 1
    
    def full_name(self):
        return f'{self.first} {self.last}'

    def apply_raise(self):
        self.pay = int(self.pay * self.raise_amt)
    

class Developer(Employee):
    raise_amt = 1.10

    def __init__(self,first,last,pay,prog_lang):
        super().__init__(first,last,pay)
        self.prog_lang = prog_lang


class Manager(Employee):
    def __init__(self,first,last,pay,employees = None):
        super().__init__(first,last,pay)
        if employees == None:
            self.employees = []
        else:
            self.employees = employees

    def add_emp(self, emp):
        if emp not in self.employees:
            self.employees.append(emp)

    def remove_emp(self,emp):
        if emp in self.employees:
            self.employees.remove(emp)
    
    def print_emps(self):
        for emp in self.employees:
            print('-->',emp.email) 
    

dev_1 = Developer('Vanya','arora',84000,'Python')
dev_2 = Developer('Kashish','singla',10000,'Java')


mgr_1 = Manager('Sue','Pitt',79000,[dev_1])


mgr_1.add_emp(dev_2)

print(mgr_1.email)
mgr_1.print_emps()


#removing an employee
mgr_1.remove_emp(dev_1)
print('priniting after removing')
mgr_1.print_emps()
# Out:
# Sue.Pitt@company.com
# --> Vanya.arora@company.com
# --> Kashish.singla@company.com
# priniting after removing
# --> Kashish.singla@company.com

# %%
class Employee:

    raise_amt = 1.04
    num_of_emps = 0

    def __init__(self,first,last,pay):
        self.first = first
        self.last = last
        self.pay = pay
        self.email = f'{first}.{last}@company.com'
        Employee.num_of_emps += 1
    
    def full_name(self):
        return f'{self.first} {self.last}'

    def apply_raise(self):
        self.pay = int(self.pay * self.raise_amt)
    

class Developer(Employee):
    raise_amt = 1.10

    def __init__(self,first,last,pay,prog_lang):
        super().__init__(first,last,pay)
        self.prog_lang = prog_lang


class Manager(Employee):
    def __init__(self,first,last,pay,employees = None):
        super().__init__(first,last,pay)
        if employees == None:
            self.employees = []
        else:
            self.employees = employees

    def add_emp(self, emp):
        if emp not in self.employees:
            self.employees.append(emp)

    def remove_emp(self,emp):
        if emp in self.employees:
            self.employees.remove(emp)
    
    def print_emps(self):
        for emp in self.employees:
            print('-->',emp.email) 
    

dev_1 = Developer('Vanya','arora',84000,'Python')
dev_2 = Developer('Kashish','singla',10000,'Java')


mgr_1 = Manager('Sue','Pitt',79000,[dev_1])

#method to check whether an object is an instance of a class or not
print(isinstance(mgr_1,Manager))
print(isinstance(mgr_1,Developer))


#checks whether a class is a sub-class of another

print(issubclass(Developer,Employee))
print(issubclass(Employee,Developer))
# Out:
# True
# False
# True
# False
